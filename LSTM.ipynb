# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Activation
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.utils.data_utils import get_file
import numpy as np
import pandas as pd
import random
import sys
import io

# %%
#read the csv file into a dataframe
df = pd.read_csv('gates.csv')
df.head()
# Out:
#                   date  ...                                          permalink
# 0  2020-04-15 05:17:26  ...  https://twitter.com/BillGates/status/125029212...
# 1  2020-04-13 00:41:08  ...  https://twitter.com/BillGates/status/124949781...
# 2  2020-04-07 20:59:04  ...  https://twitter.com/BillGates/status/124762999...
# 3  2020-04-05 22:11:06  ...  https://twitter.com/BillGates/status/124692334...
# 4  2020-04-03 20:36:07  ...  https://twitter.com/BillGates/status/124617466...
#
# [5 rows x 12 columns]

# %%
# text = all tweets
text = df['text'].str.lower()
# Out:
# on #worldhealthday — and every day — i want to thank all of the health heroes for their sacrifices and for keeping us safe.pic.twitter.com/0x9qfsrlqb

# %%
# remove any tweets shorter than 60 characters
text = text[text.str.len()>60]

# %%
#create a list containing tweets - type = string
chars = sorted(list(set(''.join(text))))
print('total chars:', len(chars))
# create character dictionary
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 1
sentences = []
next_chars = []
for x in text:
    for i in range(0, len(x) - maxlen, step):
        sentences.append(x[i: i + maxlen])
        next_chars.append(x[i + maxlen])


#vectorization
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# total chars: 75
# nb sequences: 327597
# Vectorization...

# %%
len(text)

# %%
#model using 3 layers as lstm - inspired by https://towardsdatascience.com/predicting-trump-tweets-with-a-rnn-95e7c398b18e
model = Sequential()

model.add(LSTM(len(chars) * 7, input_shape=(maxlen, len(chars))))
#model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(BatchNormalization())
model.add(Activation('selu'))

model.add(Dense(len(chars) * 4))
model.add(Activation('selu'))

model.add(Dense(len(chars) * 4))
model.add(BatchNormalization())
model.add(Activation('selu'))

model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(learning_rate=0.01)

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['categorical_crossentropy', 'accuracy'])

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)
    
#     start_index = random.randint(0, len(text) - maxlen - 1)
    tweet = np.random.choice(text) # select random tweet
    start_index = 0
  # diversity of 0.7 provides the best results
    for diversity in [0.2, 0.5, 0.7, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = tweet[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)
        # reach tweet max. 
        for i in range(120):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
# model stops learning after 10 epochs
epochs = 10

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=124,
          epochs=epochs,
          callbacks=[print_callback])
# Out:
# Epoch 1/10
# 327597/327597 [==============================] - 315s 962us/step - loss: 2.0310 - categorical_crossentropy: 2.0310 - accuracy: 0.4367
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "i’m guessing not much tweeting has been "
# i’m guessing not much tweeting has been the world the world bite and it’s and future start the poon an pover the world the unite evergate in and the world an in
# ----- diversity: 0.5
# ----- Generating with seed: "i’m guessing not much tweeting has been "
# i’m guessing not much tweeting has been an ind spen an su more learter in reart the world in see work an one the way an reaks tealth pee in we see premented one
# ----- diversity: 1.0
# ----- Generating with seed: "i’m guessing not much tweeting has been "
# i’m guessing not much tweeting has been tri#edlize few glaed8/fudji cverpic.twitter.com/mdivydmw77xsk8cff r1red1gd./g/g5ol718v60b4b …1 …at.es/2x3k6ee http://b-g
# ----- diversity: 1.2
# ----- Generating with seed: "i’m guessing not much tweeting has been "
# i’m guessing not much tweeting has been farver hestark /vengize.com/tm33g3nzwrvwlkec2:9066l-outgr2tn2zcp03116- …gm/x/7jkl5wzl #soprce’: http://b-gat.es/2dsqfro
# Epoch 2/10
# 327597/327597 [==============================] - 318s 971us/step - loss: 1.6334 - categorical_crossentropy: 1.6334 - accuracy: 0.5365
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "it’s a shame that extreme views get so m"
# it’s a shame that extreme views get so my to world to courer to the world to the world to the world to the world to the world the world to comment to be the wor
# ----- diversity: 0.5
# ----- Generating with seed: "it’s a shame that extreme views get so m"
# it’s a shame that extreme views get so make to help: http://b-gat.es/2smqeuc pic.twitter.com/9ddcnzckybfcgniwity helped to the would be would to coure the feel
# ----- diversity: 1.0
# ----- Generating with seed: "it’s a shame that extreme views get so m"
# it’s a shame that extreme views get so moge toose to fillades for you time of the reronatory questep the lear improves of thesee, ure of the womid to createwe f
# ----- diversity: 1.2
# ----- Generating with seed: "it’s a shame that extreme views get so m"
# it’s a shame that extreme views get so minv0nate me reawix1. ave gry are thas a decard, the repro 2:phttp://em.twitter.com/3zie2vnlowh5uz22vt1-96v6mbhee new mak
# Epoch 3/10
# 327597/327597 [==============================] - 305s 930us/step - loss: 1.5161 - categorical_crossentropy: 1.5161 - accuracy: 0.5699
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "tomorrow is #worldmosquitoday, when we r"
# tomorrow is #worldmosquitoday, when we read the world in my favorite for the world an excited of the country in the world in the world in change about the world
# ----- diversity: 0.5
# ----- Generating with seed: "tomorrow is #worldmosquitoday, when we r"
# tomorrow is #worldmosquitoday, when we read all end the new your armund about an interved to explain of the think about the country a don’t great better in the
# ----- diversity: 1.0
# ----- Generating with seed: "tomorrow is #worldmosquitoday, when we r"
# tomorrow is #worldmosquitoday, when we reed by aow tech of welks. count pach energy sut so no chang is a cowtyuppood countly haply holl in the visuestans of the
# ----- diversity: 1.2
# ----- Generating with seed: "tomorrow is #worldmosquitoday, when we r"
# tomorrow is #worldmosquitoday, when we rend-count frew- why conationi- a machicualmates from the 1a2dydaml. we’re ever a chastio forber mount the uns talkly is
# Epoch 4/10
# 327597/327597 [==============================] - 305s 930us/step - loss: 1.4546 - categorical_crossentropy: 1.4546 - accuracy: 0.5869
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "how can #africa provide nutritious, affo"
# how can #africa provide nutritious, affordable of the world is inspired to talked to come to down to down to to see the diseases to communities of the world is
# ----- diversity: 0.5
# ----- Generating with seed: "how can #africa provide nutritious, affo"
# how can #africa provide nutritious, affordable work. i wan be alaria is working to downroout to see the stanse in this is donation and i want to into make commi
# ----- diversity: 1.0
# ----- Generating with seed: "how can #africa provide nutritious, affo"
# how can #africa provide nutritious, afford to it’s new melindabloutmon sjeend a research essuentes from @julkeevacadationation. i can arainessen @keapffeciew po
# ----- diversity: 1.2
# ----- Generating with seed: "how can #africa provide nutritious, affo"
# how can #africa provide nutritious, affordab8,” @alwhesyww37m116 - fumusp. fial makes are dowfa20. so our inspire gozands on it’s inyoraonshow. join youally fe
# Epoch 5/10
# 327597/327597 [==============================] - 308s 939us/step - loss: 1.4199 - categorical_crossentropy: 1.4199 - accuracy: 0.5961
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "vaccines are a miracle. we have a shared"
# vaccines are a miracle. we have a shared the poorest.https://b-gat.es/2vkdwdw pic.twitter.com/kwkghkkwgqzgkgggkwgzoxhanshttps/status. the poorest the poorest.ht
# ----- diversity: 0.5
# ----- Generating with seed: "vaccines are a miracle. we have a shared"
# vaccines are a miracle. we have a shared the video: http://b-gat.es/1hkhlda pic.twitter.com/sgdywr1wwq4v0959hstatus/11553464993533 … http://b-gat.es/1ikvggn pic
# ----- diversity: 1.0
# ----- Generating with seed: "vaccines are a miracle. we have a shared"
# vaccines are a miracle. we have a shared the later how: http://b-gat.es/1vd6@hbet iversiqujphttp://b-gat.es/26aahpg pic.twitter.com/uaqfwd64lzitdgony.https://tw
# ----- diversity: 1.2
# ----- Generating with seed: "vaccines are a miracle. we have a shared"
# vaccines are a miracle. we have a shared to d talk all look ’s roge what buffcuojp2. - http://b-gat.es/1bjhb3r http://b-gat.es/j56hvn at askfig.t.es/w4ed http:/
# Epoch 6/10
# 327597/327597 [==============================] - 305s 931us/step - loss: 1.3969 - categorical_crossentropy: 1.3969 - accuracy: 0.6014
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "http://twitpic.com/1cp9f8 - was a great "
# http://twitpic.com/1cp9f8 - was a great opportunity on the great progress. this is they will to start to start to see to start to save the world. this is a grea
# ----- diversity: 0.5
# ----- Generating with seed: "http://twitpic.com/1cp9f8 - was a great "
# http://twitpic.com/1cp9f8 - was a great tool to save the possible. this explainers on his and the world and every to investment. this year. i look of the lives.
# ----- diversity: 1.0
# ----- Generating with seed: "http://twitpic.com/1cp9f8 - was a great "
# http://twitpic.com/1cp9f8 - was a great hishna to work. needemtek: http://b-gat.es/2vmjidx pic.twitter.com/wh8dlhgxswgxn62bkv7mdo2dmonv42s8565oslys will spddmen
# ----- diversity: 1.2
# ----- Generating with seed: "http://twitpic.com/1cp9f8 - was a great "
# http://twitpic.com/1cp9f8 - was a great 9terarowy. teach in cutrigrises hiv are riere ideas.https://gates/li/rieverfpquy graduatetps ourways doeaj.z. me. here:
# Epoch 7/10
# 327597/327597 [==============================] - 316s 966us/step - loss: 1.3797 - categorical_crossentropy: 1.3797 - accuracy: 0.6063
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "what i want for christmas this year (it’"
# what i want for christmas this year (it’s a better for the world’s poorest technology. here’s what is a great planes and more work and i was most with the world
# ----- diversity: 0.5
# ----- Generating with seed: "what i want for christmas this year (it’"
# what i want for christmas this year (it’s a better conting of why i’m so i was show the world’s poorest start who students move a better work will have a better
# ----- diversity: 1.0
# ----- Generating with seed: "what i want for christmas this year (it’"
# what i want for christmas this year (it’s lean eradicated for efults cooch my istory, @buce.ok. #easirmgeppic.twitter.com/ivogtd6xgzgzlpcuwnyhamemansman economi
# ----- diversity: 1.2
# ----- Generating with seed: "what i want for christmas this year (it’"
# what i want for christmas this year (it’s e0z best’s invisitors. http://b-gat.es/otclzc see of these change student good to betseeus limats: http://b-gat.es/9vj
# Epoch 8/10
# 327597/327597 [==============================] - 314s 958us/step - loss: 1.3689 - categorical_crossentropy: 1.3689 - accuracy: 0.6099
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "glad to see this story told. how nigeria"
# glad to see this story told. how nigeria to support that to support that that that ista to students to support that that that made make students to great progre
# ----- diversity: 0.5
# ----- Generating with seed: "glad to see this story told. how nigeria"
# glad to see this story told. how nigeria is for the world sharing to support here is making the fight against polio support: http://b-gat.es/18kkguf pic.twitter
# ----- diversity: 1.0
# ----- Generating with seed: "glad to see this story told. how nigeria"
# glad to see this story told. how nigeria. people of desprist. as stirlle may onpe di from pick too. here’s the work op malaria soon., http://b-gat.es/glwtngw ht
# ----- diversity: 1.2
# ----- Generating with seed: "glad to see this story told. how nigeria"
# glad to see this story told. how nigerians to this one cast to key drive to support for the phonest. him. thatsiyth whichh’s shage tethonga@wakers wise to us. g
# Epoch 9/10
# 327597/327597 [==============================] - 306s 935us/step - loss: 1.3645 - categorical_crossentropy: 1.3645 - accuracy: 0.6108
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "progress is coming faster than ever. “hi"
# progress is coming faster than ever. “highest the progress are all the place the fight against malaria started about the progress are share more about the mosqu
# ----- diversity: 0.5
# ----- Generating with seed: "progress is coming faster than ever. “hi"
# progress is coming faster than ever. “highlight agricultur optimistic the states to save millions of the mayes of the for a lot to see the possible to a last is
# ----- diversity: 1.0
# ----- Generating with seed: "progress is coming faster than ever. “hi"
# progress is coming faster than ever. “highlight: http://b-gat.es/11z5y98 pic.twitter.com/mea7hqylda7lvg8adslul8wgsggra0s98rrobicale, me subxext taughts aric of
# ----- diversity: 1.2
# ----- Generating with seed: "progress is coming faster than ever. “hi"
# progress is coming faster than ever. “his://b-gat.es/2csm858  …pic.twit-gat.es/1zpfalv @mwljitallavlet11081a …if? that’s working: httpss if thensponal economy -
# Epoch 10/10
# 327597/327597 [==============================] - 303s 926us/step - loss: 1.3603 - categorical_crossentropy: 1.3603 - accuracy: 0.6122
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "i got to check an item off my bucket lis"
# i got to check an item off my bucket list and a great progress and why: http://b-gat.es/1agypww pic.twitter.com/hwaehpphappostutudes/status/10902010880800 …http
# ----- diversity: 0.5
# ----- Generating with seed: "i got to check an item off my bucket lis"
# i got to check an item off my bucket list partnership and others are a great are learning about the world is we’ve been a great women’s commitment starting step
# ----- diversity: 1.0
# ----- Generating with seed: "i got to check an item off my bucket lis"
# i got to check an item off my bucket list? https://b-gat.es/18td9wh pic.twitter.com/0hjyyavgmvu18aopela629574acerpic.twitter.com/yupx4zhcmbrpi3ehweubmtenfaal-a
# ----- diversity: 1.2
# ----- Generating with seed: "i got to check an item off my bucket lis"
# i got to check an item off my bucket listspin my enatiingy: http://b-gat.es/29yhu6p pic.twitter.com/tqvoeewtinfydezovelvn225ap4batv i,. i’p keep about aboutay @

# %%
#sanders(260000)(len(chars)*7*4-10) = 63%
#bieber(256000)(len(chars)*7*4-10)  = 61%
#gates = 63%
#hart = 61%

# %%
#inspired by https://www.kaggle.com/talevy23/trump-tweet-generator-lstm-for-text-generation
def generate_tweets(sentence,diversity):
    # take the random sentence and diversity of 0.7 as input
    sentence = sentence[0:maxlen]
    #print('seed: ', sentence)
    generated = ''
    generated += sentence
    
    # reach max number of tweets
    for i in range(120):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.
        #predicitions
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]
        
        generated += next_char
        sentence = sentence[1:] + next_char


    print()
    # return the generated sentence in order to be read into a text file.
    return generated

# %%
# generated 20000 tweets - diversity = 0.7
tweets = []
for s in random.sample(list(text), 2000):
  for diversity in [0.7]:
      tweet = generate_w_seed(s,diversity)
      tweets.append(tweet)

# %%
print(tweets)
# Out:
# ['♛ http://shots.me/p/mwyglskz #selfiepic.twitter.com/iwez3rxt7g1p4hhdh?t= … http://instagram.com/p/feihargvlm/revix-vrelebbeht-performineorer … http://instagram.']

# %%
tweets
# Out:
# ["brace yourself people....the road to make my movie people comedy shit tickets and get ur to do in unders & scited!!!!! let's gooooooooooooooooooooooim on my com",
#  "i swear sept can’t get here fast enough....my late & i'm they are peoplefilm....don't get it on supposting mines & people called to do for my ass people. suppor",
#  'june 20th i will be there rt @sugarbell2 comedy show in comedy is in coming my city is officially special to be catch semicrion in....lets gooooooooooooooo & go',
#  "inspired by the goat/legend/mrgym himself finass....i'm cun is about to go se coming this morning....i’m about to go on saturday @icecube comment 5k level!!!! i",
#  'cracking up at this video from @tommyjohnsets so our fitnes in my fitts everyone video & i can\'t wait to make this morning!!!! why is unreal "millible" & coming']

# %%
with open('gates_generated_tweets.txt', 'w') as f:
  for i in tweets:
    f.write(i) 
    f.write('\n')
    f.write('\n')
